# %%
import pandas as pd
import numpy as np

# %%
stagione_17 = pd.read_csv("2020-21.csv", sep=',', header=None)

# %%
stagione_17['sky'] = np.where((stagione_17[4]=='SKY')  , 1, 0)
stagione_17['mediaset'] = np.where((stagione_17[4]=='PREMIUMMEDIASET'), 1, 0)
stagione_17['serieA_tv'] = np.where((stagione_17[4]=='SerieATIMTV'), 1, 0)
stagione_17['dazn'] = np.where((stagione_17[4]=='DAZN'), 1, 0)
stagione_17=stagione_17.drop([4], axis=1)
stagione_17=stagione_17.rename(columns = {0: 'squadra1', 1: 'squadra2', 2: 'data', 3: 'ora'}, inplace = False)
stagione_17.to_csv('stagione_21.csv', index=False)

# %%
stagione_17
# Out:
#              0          1           2      3     4
# 0        Parma     Napoli  20/09/2020  12:30  DAZN
# 1     Sassuolo   Cagliari  20/09/2020  18:00   SKY
# 2        Milan    Bologna  21/09/2020  20:45   SKY
# 3     Juventus  Sampdoria  20/09/2020  20:45   SKY
# 4    Benevento      Inter  30/09/2020  18:00   SKY
# ..         ...        ...         ...    ...   ...
# 193  Sampdoria      Parma  22/05/2021  20:45  DAZN
# 194   Atalanta      Milan  23/05/2021  20:45   SKY
# 195      Inter    Udinese  23/05/2021  15:00  DAZN
# 196    Bologna   Juventus  23/05/2021  20:45  DAZN
# 197   Sassuolo      Lazio  23/05/2021  20:45   SKY
#
# [198 rows x 5 columns]
